# %%
# !pip install transformers

# %%
from transformers import pipeline

generator = pipeline('text-generation', model='EleutherAI/gpt-neo-1.3B')  # You can use EleutherAI/gpt-neo-125M 'EleutherAI/gpt-neo-1.3B' for a medium-sized model

# Generate text using prompt
prompt = "Bitcoin prices in 2023 is"

res = generator(prompt, max_length=50, do_sample=True, temperature=0.9)

print(res[0]['generated_text'])
# Out:
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.31G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Bitcoin prices in 2023 is around 0.038 USD.
#
# If you want to use bitcoin, you can use bitcoin wallets such as Mycelium, Electrum, and other wallets.
#
# In the article, we'll analyze the

# %%
generator("Bitcoin prices in 2023 is",do_sample=True,max_length=120,min_length=20)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Bitcoin prices in 2023 is the only way to make sure that no one can profit from the current economic crisis, says the US Central bank.\n\nBitcoin prices in September and December 2018 were the lowest monthly prices since August 2016. The USD price of Bitcoin is, as of today, 1,000 times lower than the December 2018 peak of over $20,000.\n\nThe only possible reason why Bitcoin is up over $450 per coin in just one day is because it’s a ‘digital gold’. The next day, it falls and the value increases.\n'}]
